# %% [markdown]
# # Eco-Impact Labeler Project

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\kiit0001\eco-env\lib\site-packages (1.50.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\kiit0001\eco-env\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\kiit0001\eco-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kiit0001\eco-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\kiit0001\eco-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in c:\users\kiit0001\eco-env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kiit0001\eco-env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit0001\eco-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit0001\eco-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiit0001\eco-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit0001\eco-env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\eco-env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit0001\eco-env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit0001\eco-env\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kiit0001\eco-env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit0001\eco-env\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kiit0001\eco-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kiit0001\eco-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kiit0001\eco-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kiit0001\eco-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\eco-env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Eco-Impact Labeler: Step-by-Step Build
#
# This notebook builds an AI tool that:
# - Takes a shopping list (e.g., ['chicken', 'banana']).
# - Calculates carbon footprint (kg CO2e, assuming 0.5kg/item).
# - Suggests sustainable swaps using KNN (similarity matching).
# - Displays in a Streamlit dashboard with gamification (eco-score).

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
import streamlit as st  
print("Libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"Scikit-learn version: {NearestNeighbors().__class__.__module__}")
# Out:
# Libraries imported successfully!
# Pandas version: 2.3.3
# Scikit-learn version: sklearn.neighbors._unsupervised

# %% [markdown]
# ## Dataset Setup

# %%
# Embedded dataset (50 items—copy from previous CSV response)
data = [
    {'item': 'chicken', 'carbon_footprint_kg_per_kg': 6.9, 'category': 'meat', 'sustainable_alternative': 'lentils (legumes, nitrogen-fixing for soil)'},
    {'item': 'salmon', 'carbon_footprint_kg_per_kg': 20.0, 'category': 'fish', 'sustainable_alternative': 'mackerel (sustainable wild-caught)'},
    {'item': 'tuna', 'carbon_footprint_kg_per_kg': 6.1, 'category': 'fish', 'sustainable_alternative': 'sardines (low trophic level, abundant)'},
    {'item': 'eggs', 'carbon_footprint_kg_per_kg': 4.8, 'category': 'dairy', 'sustainable_alternative': 'fortified plant eggs (e.g., Just Egg, no animal farming)'},
    {'item': 'milk', 'carbon_footprint_kg_per_kg': 3.2, 'category': 'dairy', 'sustainable_alternative': 'oat milk (low water, renewable)'},
    {'item': 'cheese', 'carbon_footprint_kg_per_kg': 28.0, 'category': 'dairy', 'sustainable_alternative': 'almond cheese (nut-based, lower methane)'},
    {'item': 'yogurt', 'carbon_footprint_kg_per_kg': 2.2, 'category': 'dairy', 'sustainable_alternative': 'coconut yogurt (tropical, but local if possible)'},
    {'item': 'butter', 'carbon_footprint_kg_per_kg': 14.0, 'category': 'dairy', 'sustainable_alternative': 'avocado (plant fat, nutrient-dense)'},
    {'item': 'rice', 'carbon_footprint_kg_per_kg': 2.7, 'category': 'grains', 'sustainable_alternative': 'quinoa (ancient grain, drought-resistant)'},
    {'item': 'wheat_bread', 'carbon_footprint_kg_per_kg': 1.4, 'category': 'grains', 'sustainable_alternative': 'sourdough (fermented, reduces waste)'},
    {'item': 'pasta', 'carbon_footprint_kg_per_kg': 1.3, 'category': 'grains', 'sustainable_alternative': 'whole grain pasta (local wheat, fiber boost)'},
    {'item': 'potatoes', 'carbon_footprint_kg_per_kg': 0.3, 'category': 'vegetable', 'sustainable_alternative': 'sweet potatoes (similar, more vitamins)'},
    {'item': 'carrots', 'carbon_footprint_kg_per_kg': 0.2, 'category': 'vegetable', 'sustainable_alternative': 'beets (root veggies, seasonal)'},
    {'item': 'spinach', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'vegetable', 'sustainable_alternative': 'kale (leafy greens, hardy crop)'},
    {'item': 'broccoli', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'vegetable', 'sustainable_alternative': 'cauliflower (cruciferous, versatile)'},
    {'item': 'tomatoes', 'carbon_footprint_kg_per_kg': 1.4, 'category': 'vegetable', 'sustainable_alternative': 'cherry tomatoes (local greenhouse, less transport)'},
    {'item': 'lettuce', 'carbon_footprint_kg_per_kg': 0.3, 'category': 'vegetable', 'sustainable_alternative': 'arugula (fast-growing, pesticide-light)'},
    {'item': 'apples', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'fruit', 'sustainable_alternative': 'local pears (tree fruit, in-season low transport)'},
    {'item': 'bananas', 'carbon_footprint_kg_per_kg': 0.8, 'category': 'fruit', 'sustainable_alternative': 'oranges (citrus, vitamin C alternative)'},
    {'item': 'avocados', 'carbon_footprint_kg_per_kg': 2.5, 'category': 'fruit', 'sustainable_alternative': 'seasonal berries (strawberries, lower water needs)'},
    {'item': 'strawberries', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'fruit', 'sustainable_alternative': 'blueberries (antioxidants, pollinator-friendly)'},
    {'item': 'oranges', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'fruit', 'sustainable_alternative': 'grapefruit (citrus family, similar freshness)'},
    {'item': 'almonds', 'carbon_footprint_kg_per_kg': 2.1, 'category': 'nuts', 'sustainable_alternative': 'peanuts (legume nut, less irrigation)'},
    {'item': 'peanuts', 'carbon_footprint_kg_per_kg': 0.8, 'category': 'nuts', 'sustainable_alternative': 'sunflower seeds (easy to grow, omega-3s)'},
    {'item': 'chocolate', 'carbon_footprint_kg_per_kg': 19.0, 'category': 'snack', 'sustainable_alternative': 'dark chocolate (cocoa fair-trade, minimal sugar)'},
    {'item': 'cookies', 'carbon_footprint_kg_per_kg': 3.5, 'category': 'snack', 'sustainable_alternative': 'oat bars (homemade, whole ingredients)'},
    {'item': 'chips', 'carbon_footprint_kg_per_kg': 2.0, 'category': 'snack', 'sustainable_alternative': 'popcorn (corn-based, air-popped low oil)'},
    {'item': 'coffee', 'carbon_footprint_kg_per_kg': 3.3, 'category': 'beverage', 'sustainable_alternative': 'tea (herbal, lower deforestation risk)'},
    {'item': 'wine', 'carbon_footprint_kg_per_kg': 2.5, 'category': 'beverage', 'sustainable_alternative': 'milk (short supply chain)'},
    {'item': 'soy_milk', 'carbon_footprint_kg_per_kg': 0.8, 'category': 'dairy', 'sustainable_alternative': 'pea milk (innovative, low allergen)'},
    {'item': 'tofu', 'carbon_footprint_kg_per_kg': 2.0, 'category': 'protein', 'sustainable_alternative': 'edamame (whole soy, fresh protein)'},
    {'item': 'quinoa', 'carbon_footprint_kg_per_kg': 1.6, 'category': 'grains', 'sustainable_alternative': 'millet (gluten-free, water-efficient)'},
    {'item': 'oats', 'carbon_footprint_kg_per_kg': 0.9, 'category': 'grains', 'sustainable_alternative': 'barley (ancient, soil health benefits)'},
    {'item': 'beans', 'carbon_footprint_kg_per_kg': 0.8, 'category': 'protein', 'sustainable_alternative': 'peas (nitrogen-fixing, versatile)'},
    {'item': 'lentils', 'carbon_footprint_kg_per_kg': 0.9, 'category': 'protein', 'sustainable_alternative': 'chickpeas (hummus base, global staple)'},
    {'item': 'mushrooms', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'vegetable', 'sustainable_alternative': 'shiitake (fungi, no tilling needed)'},
    {'item': 'onions', 'carbon_footprint_kg_per_kg': 0.4, 'category': 'vegetable', 'sustainable_alternative': 'garlic (alliums, flavor enhancers)'},
    {'item': 'peppers', 'carbon_footprint_kg_per_kg': 0.9, 'category': 'vegetable', 'sustainable_alternative': 'zucchini (summer squash, prolific yield)'},
    {'item': 'cabbage', 'carbon_footprint_kg_per_kg': 0.3, 'category': 'vegetable', 'sustainable_alternative': 'brussels sprouts (brassica, cold-hardy)'},
    {'item': 'lemons', 'carbon_footprint_kg_per_kg': 0.9, 'category': 'fruit', 'sustainable_alternative': 'limes (citrus, interchangeable in recipes)'},
    {'item': 'honey', 'carbon_footprint_kg_per_kg': 1.2, 'category': 'sweetener', 'sustainable_alternative': 'maple syrup (tree sap, sustainable tapping)'},
    {'item': 'sugar', 'carbon_footprint_kg_per_kg': 0.6, 'category': 'sweetener', 'sustainable_alternative': 'date syrup (fruit-based, natural)'},
    {'item': 'olive_oil', 'carbon_footprint_kg_per_kg': 3.2, 'category': 'oil', 'sustainable_alternative': 'canola oil (rapeseed, lower land use)'},
    {'item': 'coconut_oil', 'carbon_footprint_kg_per_kg': 1.5, 'category': 'oil', 'sustainable_alternative': 'sunflower oil (annual crop, high yield)'},
    {'item': 'bread', 'carbon_footprint_kg_per_kg': 1.4, 'category': 'grains', 'sustainable_alternative': 'flatbread (e.g., naan with local flour)'},
    {'item': 'pizza', 'carbon_footprint_kg_per_kg': 4.0, 'category': 'snack', 'sustainable_alternative': 'veggie wrap (tortilla with plants, customizable)'},
    {'item': 'ice_cream', 'carbon_footprint_kg_per_kg': 3.0, 'category': 'dairy', 'sustainable_alternative': 'sorbet (fruit-based, dairy-free)'}
]

df = pd.DataFrame(data)
print("Dataset loaded! Shape:", df.shape)
print(df.head(10))
print("\nStats:")
print(df['carbon_footprint_kg_per_kg'].describe())
# Out:
# Dataset loaded! Shape: (47, 4)
#           item  carbon_footprint_kg_per_kg category  \
# 0      chicken                         6.9     meat
# 1       salmon                        20.0     fish
# 2         tuna                         6.1     fish
# 3         eggs                         4.8    dairy
# 4         milk                         3.2    dairy
# 5       cheese                        28.0    dairy
# 6       yogurt                         2.2    dairy
# 7       butter                        14.0    dairy
# 8         rice                         2.7   grains
# 9  wheat_bread                         1.4   grains
#
#                              sustainable_alternative
# 0        lentils (legumes, nitrogen-fixing for soil)
# 1                 mackerel (sustainable wild-caught)
# 2             sardines (low trophic level, abundant)
# 3  fortified plant eggs (e.g., Just Egg, no anima...
# 4                    oat milk (low water, renewable)
# 5           almond cheese (nut-based, lower methane)
# 6   coconut yogurt (tropical, but local if possible)
# 7                avocado (plant fat, nutrient-dense)
# 8          quinoa (ancient grain, drought-resistant)
# 9               sourdough (fermented, reduces waste)
#
# Stats:
# count    47.000000
# mean      3.321277
# std       5.628883
# min       0.200000
# 25%       0.700000
# 50%       1.400000
# 75%       3.100000
# max      28.000000
# Name: carbon_footprint_kg_per_kg, dtype: float64

# %%
df_encoded = pd.get_dummies(df, columns=['category'])
features = df_encoded.drop(['item', 'sustainable_alternative'], axis=1)
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
knn = NearestNeighbors(n_neighbors=3, algorithm='auto')
knn.fit(features_scaled)

print("KNN fitted! Features shape:", features_scaled.shape)
print("\nSample encoded data:")
print(features.head(3))
# Out:
# KNN fitted! Features shape: (47, 13)
#
# Sample encoded data:
#    carbon_footprint_kg_per_kg  category_beverage  category_dairy  \
# 0                         6.9              False           False
# 1                        20.0              False           False
# 2                         6.1              False           False
#
#    category_fish  category_fruit  category_grains  category_meat  \
# 0          False           False            False           True
# 1           True           False            False          False
# 2           True           False            False          False
#
#    category_nuts  category_oil  category_protein  category_snack  \
# 0          False         False             False           False
# 1          False         False             False           False
# 2          False         False             False           False
#
#    category_sweetener  category_vegetable
# 0               False               False
# 1               False               False
# 2               False               False

# %% [markdown]
# ## Core Functions

# %%
def calculate_impact(shopping_list):
    """
    Input: List of strings, e.g., ['chicken', 'banana']
    Output: Dict with total carbon score, per-item breakdown, tip, and unknowns.
    Assumes 0.5kg per item (customize later for quantities).
    """
    total_impact = 0
    impacts = {}
    unknown_items = []
    
    for item in shopping_list:
        item_lower = item.lower().strip()
        match = df[df['item'].str.lower() == item_lower]
        if not match.empty:
            footprint = match['carbon_footprint_kg_per_kg'].iloc[0]
            impacts[item] = footprint * 0.5 
            total_impact += impacts[item]
        else:
            unknown_items.append(item)
            impacts[item] = 0  
    
    
    if total_impact > 10:
        tip = "High impact! Aim for more plants to reduce by 50% "
    elif total_impact > 5:
        tip = "Moderate—swap meats for veggies. You're on the way!"
    else:
        tip = "Eco-friendly list! Keep it up—you're saving the planet! "
    
    return {
        'total_impact': round(total_impact, 2),
        'impacts': impacts,
        'tip': tip,
        'unknown_items': unknown_items
    }
print("Function defined. Example usage: calculate_impact(['chicken'])")
# Out:
# Function defined. Example usage: calculate_impact(['chicken'])

# %%
def get_swaps(shopping_list):
    """
    Input: List of strings (same as above).
    Output: Dict of {item: suggested_alternative} using KNN for similarity.
    Picks the first (best) neighbor's alternative.
    """
    swaps = {}
    for item in shopping_list:
        item_lower = item.lower().strip()
        match_idx = df[df['item'].str.lower() == item_lower].index
        if len(match_idx) > 0:
            idx = match_idx[0]
            distances, indices = knn.kneighbors([features_scaled[idx]])
            
            neighbor_indices = [i for i in indices[0] if i != idx]
            if neighbor_indices:
                best_neighbor_idx = neighbor_indices[0]  
                swaps[item] = df.iloc[best_neighbor_idx]['sustainable_alternative']
            else:
                swaps[item] = df.iloc[indices[0][0]]['sustainable_alternative'] 
        else:
            swaps[item] = "Search for plant-based alternative (e.g., via Open Food Facts API)"
    
    
    for item in swaps:
        swaps[item] += " (saves ~5-20kg CO2!)"
    
    return swaps

print("Swaps function defined. Example usage: get_swaps(['chicken'])")
# Out:
# Swaps function defined. Example usage: get_swaps(['chicken'])

# %% [markdown]
# ## Testing the Functions

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata (114 kB)
#      ---------------------------------------- 0.0/114.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/114.6 kB ? eta -:--:--
#      --------- --------------------------- 30.7/114.6 kB 445.2 kB/s eta 0:00:01
#      -------------------------------------  112.6/114.6 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 114.6/114.6 kB 957.1 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\kiit0001\eco-env\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit0001\eco-env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kiit0001\eco-env\lib\site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit0001\eco-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\eco-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/8.1 MB 13.4 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/8.1 MB 805.8 kB/s eta 0:00:10
#    ---- ----------------------------------- 0.9/8.1 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.5/8.1 MB 2.1 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 2.0 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/8.1 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.3/8.1 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 2.8/8.1 MB 3.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.6/8.1 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.0/8.1 MB 3.7 MB/s eta 0:00:02
#    --------------------- ------------------ 4.3/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.1 MB 4.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.1 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.9/8.1 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 4.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.7/8.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.1 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.1 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
#    ---------------------------------------- 0.0/226.6 kB ? eta -:--:--
#    ---------------------------------------- 226.6/226.6 kB 7.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.3 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.3 MB 10.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.3 MB 9.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.3 MB 9.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.3 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.9 kB ? eta -:--:--
#    ---------------------------------------- 73.9/73.9 kB 2.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.9 kB ? eta -:--:--
#    ---------------------------------------- 113.9/113.9 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
shopping_list1 = ['chicken', 'banana']
impact1 = calculate_impact(shopping_list1)
swaps1 = get_swaps(shopping_list1)

print("=== Test 1: Known Items ===")
print("Impact:", impact1)
print("Swaps:", swaps1)

shopping_list2 = ['chicken', 'banana', 'exotic_fruit']
impact2 = calculate_impact(shopping_list2)
swaps2 = get_swaps(shopping_list2)

print("\n=== Test 2: With Unknown ===")
print("Impact:", impact2)
print("Swaps:", swaps2)

shopping_list3 = ['apples', 'spinach', 'oats']
impact3 = calculate_impact(shopping_list3)
print("\n=== Test 3: Low-Impact List ===")
print("Impact:", impact3)

import matplotlib.pyplot as plt

items = list(impact1['impacts'].keys())
values = list(impact1['impacts'].values())

plt.figure(figsize=(8, 4))
plt.bar(items, values, color=['red' if v > 5 else 'green' for v in values])
plt.title("Carbon Impact per Item (Test 1)")
plt.ylabel("kg CO2e (for 0.5kg)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# === Test 1: Known Items ===
# Impact: {'total_impact': np.float64(3.45), 'impacts': {'chicken': np.float64(3.45), 'banana': 0}, 'tip': "Eco-friendly list! Keep it up—you're saving the planet! 🌍", 'unknown_items': ['banana']}
# Swaps: {'chicken': 'cherry tomatoes (local greenhouse, less transport) (saves ~5-20kg CO2!)', 'banana': 'Search for plant-based alternative (e.g., via Open Food Facts API) (saves ~5-20kg CO2!)'}
#
# === Test 2: With Unknown ===
# Impact: {'total_impact': np.float64(3.45), 'impacts': {'chicken': np.float64(3.45), 'banana': 0, 'exotic_fruit': 0}, 'tip': "Eco-friendly list! Keep it up—you're saving the planet! 🌍", 'unknown_items': ['banana', 'exotic_fruit']}
# Swaps: {'chicken': 'cherry tomatoes (local greenhouse, less transport) (saves ~5-20kg CO2!)', 'banana': 'Search for plant-based alternative (e.g., via Open Food Facts API) (saves ~5-20kg CO2!)', 'exotic_fruit': 'Search for plant-based alternative (e.g., via Open Food Facts API) (saves ~5-20kg CO2!)'}
#
# === Test 3: Low-Impact List ===
# Impact: {'total_impact': np.float64(0.85), 'impacts': {'apples': np.float64(0.2), 'spinach': np.float64(0.2), 'oats': np.float64(0.45)}, 'tip': "Eco-friendly list! Keep it up—you're saving the planet! 🌍", 'unknown_items': []}
#
# All tests complete! If plots show and outputs match expectations, success! 🎉
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_14724\2795209311.py:37: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Streamlit Dashboard (UI)

# %%
     app_code = '''
     import pandas as pd
     import numpy as np
     from sklearn.preprocessing import StandardScaler
     from sklearn.neighbors import NearestNeighbors
     import streamlit as st

     # Embedded dataset (PASTE FULL 50-ITEM LIST FROM CELL 4 HERE)
     data = [
         {"item": "chicken", "carbon_footprint_kg_per_kg": 6.9, "category": "meat", "sustainable_alternative": "lentils (legumes, nitrogen-fixing for soil)"},
         {"item": "salmon", "carbon_footprint_kg_per_kg": 20.0, "category": "fish", "sustainable_alternative": "mackerel (sustainable wild-caught)"},
         {"item": "tuna", "carbon_footprint_kg_per_kg": 6.1, "category": "fish", "sustainable_alternative": "sardines (low trophic level, abundant)"},
         {"item": "eggs", "carbon_footprint_kg_per_kg": 4.8, "category": "dairy", "sustainable_alternative": "fortified plant eggs (e.g., Just Egg, no animal farming)"},
         {"item": "milk", "carbon_footprint_kg_per_kg": 3.2, "category": "dairy", "sustainable_alternative": "oat milk (low water, renewable)"},
         {"item": "cheese", "carbon_footprint_kg_per_kg": 28.0, "category": "dairy", "sustainable_alternative": "almond cheese (nut-based, lower methane)"},
         {"item": "yogurt", "carbon_footprint_kg_per_kg": 2.2, "category": "dairy", "sustainable_alternative": "coconut yogurt (tropical, but local if possible)"},
         {"item": "butter", "carbon_footprint_kg_per_kg": 14.0, "category": "dairy", "sustainable_alternative": "avocado (plant fat, nutrient-dense)"},
         {"item": "rice", "carbon_footprint_kg_per_kg": 2.7, "category": "grains", "sustainable_alternative": "quinoa (ancient grain, drought-resistant)"},
         {"item": "wheat_bread", "carbon_footprint_kg_per_kg": 1.4, "category": "grains", "sustainable_alternative": "sourdough (fermented, reduces waste)"},
         {"item": "pasta", "carbon_footprint_kg_per_kg": 1.3, "category": "grains", "sustainable_alternative": "whole grain pasta (local wheat, fiber boost)"},
         {"item": "potatoes", "carbon_footprint_kg_per_kg": 0.3, "category": "vegetable", "sustainable_alternative": "sweet potatoes (similar, more vitamins)"},
         {"item": "carrots", "carbon_footprint_kg_per_kg": 0.2, "category": "vegetable", "sustainable_alternative": "beets (root veggies, seasonal)"},
         {"item": "spinach", "carbon_footprint_kg_per_kg": 0.4, "category": "vegetable", "sustainable_alternative": "kale (leafy greens, hardy crop)"},
         {"item": "broccoli", "carbon_footprint_kg_per_kg": 0.4, "category": "vegetable", "sustainable_alternative": "cauliflower (cruciferous, versatile)"},
         {"item": "tomatoes", "carbon_footprint_kg_per_kg": 1.4, "category": "vegetable", "sustainable_alternative": "cherry tomatoes (local greenhouse, less transport)"},
         {"item": "lettuce", "carbon_footprint_kg_per_kg": 0.3, "category": "vegetable", "sustainable_alternative": "arugula (fast-growing, pesticide-light)"},
         {"item": "apples", "carbon_footprint_kg_per_kg": 0.4, "category": "fruit", "sustainable_alternative": "local pears (tree fruit, in-season low transport)"},
         {"item": "bananas", "carbon_footprint_kg_per_kg": 0.8, "category": "fruit", "sustainable_alternative": "oranges (citrus, vitamin C alternative)"},
         {"item": "avocados", "carbon_footprint_kg_per_kg": 2.5, "category": "fruit", "sustainable_alternative": "seasonal berries (strawberries, lower water needs)"},
         {"item": "strawberries", "carbon_footprint_kg_per_kg": 0.4, "category": "fruit", "sustainable_alternative": "blueberries (antioxidants, pollinator-friendly)"},
         {"item": "oranges", "carbon_footprint_kg_per_kg": 0.4, "category": "fruit", "sustainable_alternative": "grapefruit (citrus family, similar freshness)"},
         {"item": "almonds", "carbon_footprint_kg_per_kg": 2.1, "category": "nuts", "sustainable_alternative": "peanuts (legume nut, less irrigation)"},
         {"item": "peanuts", "carbon_footprint_kg_per_kg": 0.8, "category": "nuts", "sustainable_alternative": "sunflower seeds (easy to grow, omega-3s)"},
         {"item": "chocolate", "carbon_footprint_kg_per_kg": 19.0, "category": "snack", "sustainable_alternative": "dark chocolate (cocoa fair-trade, minimal sugar)"},
         {"item": "cookies", "carbon_footprint_kg_per_kg": 3.5, "category": "snack", "sustainable_alternative": "oat bars (homemade, whole ingredients)"},
         {"item": "chips", "carbon_footprint_kg_per_kg": 2.0, "category": "snack", "sustainable_alternative": "popcorn (corn-based, air-popped low oil)"},
         {"item": "coffee", "carbon_footprint_kg_per_kg": 3.3, "category": "beverage", "sustainable_alternative": "tea (herbal, lower deforestation risk)"},
         {"item": "wine", "carbon_footprint_kg_per_kg": 2.5, "category": "beverage", "sustainable_alternative": "local milk (short supply chain)"},
         {"item": "soy_milk", "carbon_footprint_kg_per_kg": 0.8, "category": "dairy", "sustainable_alternative": "pea milk (innovative, low allergen)"},
         {"item": "tofu", "carbon_footprint_kg_per_kg": 2.0, "category": "protein", "sustainable_alternative": "edamame (whole soy, fresh protein)"},
         {"item": "quinoa", "carbon_footprint_kg_per_kg": 1.6, "category": "grains", "sustainable_alternative": "millet (gluten-free, water-efficient)"},
         {"item": "oats", "carbon_footprint_kg_per_kg": 0.9, "category": "grains", "sustainable_alternative": "barley (ancient, soil health benefits)"},
         {"item": "beans", "carbon_footprint_kg_per_kg": 0.8, "category": "protein", "sustainable_alternative": "peas (nitrogen-fixing, versatile)"},
         {"item": "lentils", "carbon_footprint_kg_per_kg": 0.9, "category": "protein", "sustainable_alternative": "chickpeas (hummus base, global staple)"},
         {"item": "mushrooms", "carbon_footprint_kg_per_kg": 0.4, "category": "vegetable", "sustainable_alternative": "shiitake (fungi, no tilling needed)"},
         {"item": "onions", "carbon_footprint_kg_per_kg": 0.4, "category": "vegetable", "sustainable_alternative": "garlic (alliums, flavor enhancers)"},
         {"item": "peppers", "carbon_footprint_kg_per_kg": 0.9, "category": "vegetable", "sustainable_alternative": "zucchini (summer squash, prolific yield)"},
         {"item": "cabbage", "carbon_footprint_kg_per_kg": 0.3, "category": "vegetable", "sustainable_alternative": "brussels sprouts (brassica, cold-hardy)"},
         {"item": "lemons", "carbon_footprint_kg_per_kg": 0.9, "category": "fruit", "sustainable_alternative": "limes (citrus, interchangeable in recipes)"},
         {"item": "honey", "carbon_footprint_kg_per_kg": 1.2, "category": "sweetener", "sustainable_alternative": "maple syrup (tree sap, sustainable tapping)"},
         {"item": "sugar", "carbon_footprint_kg_per_kg": 0.6, "category": "sweetener", "sustainable_alternative": "date syrup (fruit-based, natural)"},
         {"item": "olive_oil", "carbon_footprint_kg_per_kg": 3.2, "category": "oil", "sustainable_alternative": "canola oil (rapeseed, lower land use)"},
         {"item": "coconut_oil", "carbon_footprint_kg_per_kg": 1.5, "category": "oil", "sustainable_alternative": "sunflower oil (annual crop, high yield)"},
         {"item": "bread", "carbon_footprint_kg_per_kg": 1.4, "category": "grains", "sustainable_alternative": "flatbread (e.g., naan with local flour)"},
         {"item": "pizza", "carbon_footprint_kg_per_kg": 4.0, "category": "snack", "sustainable_alternative": "veggie wrap (tortilla with plants, customizable)"},
         {"item": "ice_cream", "carbon_footprint_kg_per_kg": 3.0, "category": "dairy", "sustainable_alternative": "sorbet (fruit-based, dairy-free)"}
     ]

     df = pd.DataFrame(data)

     df_encoded = pd.get_dummies(df, columns=['category'])
     features = df_encoded.drop(['item', 'sustainable_alternative'], axis=1)
     scaler = StandardScaler()
     features_scaled = scaler.fit_transform(features)
     knn = NearestNeighbors(n_neighbors=3, algorithm='auto')
     knn.fit(features_scaled)

     def calculate_impact(shopping_list):
         total_impact = 0
         impacts = {}
         unknown_items = []
         
         for item in shopping_list:
             item_lower = item.lower().strip()
             match = df[df['item'].str.lower() == item_lower]
             if not match.empty:
                 footprint = match['carbon_footprint_kg_per_kg'].iloc[0]
                 impacts[item] = footprint * 0.5  # 0.5kg assumption
                 total_impact += impacts[item]
             else:
                 unknown_items.append(item)
                 impacts[item] = 0

         if total_impact > 10:
             tip = "High impact! Aim for more plants to reduce by 50% "
         elif total_impact > 5:
             tip = "Moderate—swap meats for veggies. You're on the way!"
         else:
             tip = "Eco-friendly list! Keep it up—you're saving the planet! "
         
         return {
             'total_impact': round(total_impact, 2),
             'impacts': impacts,
             'tip': tip,
             'unknown_items': unknown_items
         }

    
     def get_swaps(shopping_list):
         swaps = {}
         for item in shopping_list:
             item_lower = item.lower().strip()
             match_idx = df[df['item'].str.lower() == item_lower].index
             if len(match_idx) > 0:
                 idx = match_idx[0]
                 distances, indices = knn.kneighbors([features_scaled[idx]])
                 neighbor_indices = [i for i in indices[0] if i != idx]
                 if neighbor_indices:
                     best_neighbor_idx = neighbor_indices[0]
                     swaps[item] = df.iloc[best_neighbor_idx]['sustainable_alternative']
                 else:
                     swaps[item] = df.iloc[indices[0][0]]['sustainable_alternative']
             else:
                 swaps[item] = "Search for plant-based alternative (e.g., via Open Food Facts API)"
         
         
         for item in swaps:
             swaps[item] += " (saves ~5-20kg CO2!)"
         
         return swaps

     def main():
         st.title("Eco-Impact Labeler: Make Your Shopping Sustainable!") 
         st.write("Enter your grocery list (one item per line) and get a carbon score + green swaps!")

         shopping_list_input = st.text_area("Your Shopping List:", placeholder="e.g., chicken\\nbanana\\nrice", height=150)
         
         if st.button("Calculate Impact"):
             if shopping_list_input:
                 shopping_list = [line.strip() for line in shopping_list_input.split('\\n') if line.strip()]
                 
                
                 impact_result = calculate_impact(shopping_list)
                 swaps = get_swaps(shopping_list)
                 
                 
                 col1, col2 = st.columns(2)
                 with col1:
                     st.metric("Total Carbon Footprint (kg CO2e)", impact_result['total_impact'])
                     st.write("**Per-Item Breakdown:**")
                     for item, score in impact_result['impacts'].items():
                         st.write(f"- **{item}**: {score} kg")
                 
                 with col2:
                     st.write("**Sustainable Swaps:**")
                     for item, swap in swaps.items():
                         st.write(f"- {item} → {swap}")
                 
                 eco_score = max(0, 100 - (impact_result['total_impact'] * 10))
                 st.progress(eco_score / 100)
                 st.success(f"Your Eco-Score: {eco_score:.0f}/100 ")
                 st.info(impact_result['tip'])
                 
                 if impact_result['unknown_items']:
                     st.warning(f"Unknown items: {', '.join(impact_result['unknown_items'])}. Add to dataset or use API!")
             
             else:
                 st.warning("Add some items to your list!")

     if __name__ == "__main__":
         main()
     '''

     with open('app.py', 'w', encoding='utf-8') as f:
         f.write(app_code)
